# %% [markdown]
# <a href="https://colab.research.google.com/github/Chopra-14/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key:')
# Out:
# Paste your Google AI Studio key:··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the hierarchical skills needed for successful AI adoption, from foundational to strategic:
#
# *   **Foundational Infrastructure:** The base layer, focused on data collection, storage, processing, and computational resources, ensuring data readiness and accessibility.
# *   **ML Development & Engineering:** Involves building, training, and deploying machine learning models, covering algorithms, platforms, and MLOps for robust and scalable solutions.
# *   **Domain Expertise & Application:** Focuses on applying AI solutions to specific business problems, requiring deep understanding of the industry, user needs, and problem framing.
# *   **AI Strategy & Leadership:** The apex layer, involving setting AI vision, ethical guidelines, governance, organizational adoption, and aligning AI initiatives with business goals.
